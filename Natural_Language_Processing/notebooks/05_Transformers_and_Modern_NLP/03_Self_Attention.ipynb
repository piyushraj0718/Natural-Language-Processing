# %% [markdown]
# # Self-Attention
#
# ## Definition
# Self-Attention (also called Intra-Attention) is a mechanism where each token in a sequence attends to all other tokens in the same sequence to compute a contextualized representation. Unlike standard attention (which relates encoder to decoder states), self-attention relates each position in a sequence to every other position within the same sequence, enabling the model to capture long-range dependencies without recurrence.
#
# ## Why It Is Needed
# - **Parallel Processing:** Unlike RNNs, self-attention processes all tokens simultaneously — enabling massive parallelization on GPUs.
# - **Long-Range Dependencies:** Captures relationships between any two tokens regardless of their distance in the sequence — no vanishing gradient over distance.
# - **Contextual Representations:** Each token's representation is updated based on its relationship to all other tokens, producing deeply contextual embeddings.
#
# ## Real-World Applications
# - Core computation in all Transformer-based models (BERT, GPT, T5, etc.)
# - Coreference resolution (e.g., linking `it` to `the cat` in a sentence)
# - Dependency parsing — identifying syntactic relationships between words
# - Semantic role labeling
# - Any NLP task requiring understanding of word relationships within a sentence
#
# ## Important Points
# - **Query, Key, Value (Q, K, V):** The three projections at the heart of self-attention.
#   - **Query (Q):** What the current token is looking for.
#   - **Key (K):** What each token offers or represents.
#   - **Value (V):** The actual content to be aggregated.
# - **Scaled Dot-Product Attention Formula:**
#   - `Attention(Q, K, V) = softmax( Q·Kᵀ / √dₖ ) · V`
#   - `dₖ` = dimension of key vectors (scaling factor to prevent vanishing gradients from large dot products).
# - **Attention Matrix:** An N×N matrix (N = sequence length) where each cell `[i,j]` holds the attention weight of token `i` attending to token `j`.
# - **Why Scale by √dₖ?** Without scaling, dot products grow large in magnitude with high-dimensional keys, pushing softmax into saturation regions with near-zero gradients.
# - Q, K, V are all linear projections of the same input sequence — hence `self`-attention.
#
#
#
# ## Implementation
# Practical implementation will be added here.
#
# ## Key Takeaways
# - Self-attention relates every token in a sequence to every other token simultaneously.
# - Q (Query), K (Key), V (Value) are the three learnable projections in self-attention.
# - The formula: `softmax(QKᵀ / √dₖ) · V` — must be memorized for interviews.
# - Scaling by `√dₖ` prevents softmax saturation and ensures stable gradients.
# - Self-attention replaces recurrence entirely, enabling full parallelization in Transformers.

# %% [markdown]
# ## Scaled Dot Product Attention

# %%
import numpy as np

# Step 1: Compute dot product of query and keys
def compute_scores(Q, K):
    return np.dot(Q, K.T)

# Step 2: Scale the scores by the square root of the dimension of keys
def scale_scores(scores, d_k):
    return scores / np.sqrt(d_k)

# Step 3: Apply softmax function to the scores
def softmax(scores):
    exp_scores = np.exp(scores - np.max(scores))  # Numerical stability trick
    return exp_scores / np.sum(exp_scores, axis=-1, keepdims=True)

# Step 4: Compute the weighted sum of the values
def compute_attention_output(attention_weights, V):
    return np.dot(attention_weights, V)

# Main attention function
def attention(Q, K, V):
    d_k = Q.shape[-1]  # Assuming query and key have same dimension
    scores = compute_scores(Q, K)
    scaled_scores = scale_scores(scores, d_k)
    attention_weights = softmax(scaled_scores)
    output = compute_attention_output(attention_weights, V)
    return output, attention_weights

# Example input: query, keys, and values
Q = np.array([[1, 0]])  # Query
K = np.array([[1, 0], [0, 1], [1, 1]])  # Keys
V = np.array([[1, 1], [0, 1], [1, 0]])  # Values

# Apply attention
output, attention_weights = attention(Q, K, V)

print("Output of Attention:", output)
print("Attention Weights:", attention_weights)
# Out:
# Output of Attention: [[0.80222419 0.59888791]]
# Attention Weights: [[0.40111209 0.19777581 0.40111209]]

# %% [markdown]
# ## Text Classification

# %%
import tensorflow as tf
import numpy as np

# Sample data
sentences = [
    'I love programming',
    'I hate bugs',
    'bugs are annoying',
    'programming is awesome',
    'I enjoy coding',
    'I despise errors',
    'errors make me sad',
    'coding makes me happy'
]
labels = [1, 0, 0, 1, 1, 0, 0, 1]  # 1 = Positive, 0 = Negative

# Build vocabulary
tokenizer = tf.keras.preprocessing.text.Tokenizer(lower=True, oov_token='<OOV>')
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # Add 1 for padding

# Convert to sequences and pad
sequences = tokenizer.texts_to_sequences(sentences)
X = tf.keras.preprocessing.sequence.pad_sequences(sequences, padding='post')
y = np.array(labels)

# Parameters
embedding_dim = 16
hidden_dim = 16
output_dim = 2
maxlen = X.shape[1]

# Self-Attention layer
class SelfAttention(tf.keras.layers.Layer):
    def __init__(self, hidden_dim):
        super(SelfAttention, self).__init__()
        self.W_q = tf.keras.layers.Dense(hidden_dim)
        self.W_k = tf.keras.layers.Dense(hidden_dim)
        self.W_v = tf.keras.layers.Dense(hidden_dim)

    def call(self, inputs):
        Q = self.W_q(inputs)
        K = self.W_k(inputs)
        V = self.W_v(inputs)
        scores = tf.matmul(Q, K, transpose_b=True)
        dim_k = tf.cast(tf.shape(K)[-1], tf.float32)
        scaled_scores = scores / tf.math.sqrt(dim_k)
        attention_weights = tf.nn.softmax(scaled_scores, axis=-1)
        context = tf.matmul(attention_weights, V)
        return context

# Build model
inputs = tf.keras.Input(shape=(maxlen,))
x = tf.keras.layers.Embedding(vocab_size, embedding_dim)(inputs)
x = SelfAttention(hidden_dim)(x)
x = tf.keras.layers.GlobalAveragePooling1D()(x)  # ✅ Fixed
x = tf.keras.layers.Dense(16, activation='relu')(x)
outputs = tf.keras.layers.Dense(output_dim, activation='softmax')(x)

model = tf.keras.Model(inputs, outputs)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Train
model.fit(X, y, epochs=30, verbose=1)

# Prediction function
def predict_sentiment(text):
    seq = tokenizer.texts_to_sequences([text])
    padded = tf.keras.preprocessing.sequence.pad_sequences(seq, maxlen=maxlen, padding='post')
    probs = model.predict(padded)[0]
    label = np.argmax(probs)
    sentiment = "Positive 😊" if label == 1 else "Negative 😒"
    print(f"Input: {text}")
    print(f"Prediction: {sentiment} | Probabilities: {probs}")

# Test predictions
predict_sentiment("I love coding")
predict_sentiment("bugs make me cry")
predict_sentiment("programming is fun")
predict_sentiment("I hate syntax errors")
# Out:
# Epoch 1/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6250 - loss: 0.6921
# Epoch 2/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.6898
# Epoch 3/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8750 - loss: 0.6880
# Epoch 4/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8750 - loss: 0.6862
# Epoch 5/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8750 - loss: 0.6846
# Epoch 6/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8750 - loss: 0.6829
# Epoch 7/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.6812
# Epoch 8/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 1.0000 - loss: 0.6796
# Epoch 9/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.6779
# Epoch 10/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.6761
# Epoch 11/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 1.0000 - loss: 0.6740
# Epoch 12/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.6718
# Epoch 13/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.6694
# Epoch 14/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.6668
# Epoch 15/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.6640
# Epoch 16/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 1.0000 - loss: 0.6610
# Epoch 17/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.6578
# Epoch 18/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 1.0000 - loss: 0.6542
# Epoch 19/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.6502
# Epoch 20/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.6460
# Epoch 21/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 1.0000 - loss: 0.6414
# Epoch 22/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 1.0000 - loss: 0.6367
# Epoch 23/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.6318
# Epoch 24/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.6266
# Epoch 25/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 1.0000 - loss: 0.6211
# Epoch 26/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.6155
# Epoch 27/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 1.0000 - loss: 0.6096
# Epoch 28/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 1.0000 - loss: 0.6035
# Epoch 29/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 1.0000 - loss: 0.5972
# Epoch 30/30
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 1.0000 - loss: 0.5905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Input: I love coding
# Prediction: Positive 😊 | Probabilities: [0.45006958 0.54993033]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Input: bugs make me cry
# Prediction: Negative 😒 | Probabilities: [0.5440259  0.45597413]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Input: programming is fun
# Prediction: Positive 😊 | Probabilities: [0.45133147 0.54866856]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Input: I hate syntax errors
# Prediction: Negative 😒 | Probabilities: [0.5530318  0.44696823]
